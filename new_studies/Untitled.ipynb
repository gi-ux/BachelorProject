# %%
import pandas as pd
import numpy as np
import os
import warnings
warnings.filterwarnings('ignore')
import time
from time import perf_counter
import glob
import csv
import importlib
import seaborn as sns
import json
from tqdm.notebook import tqdm
import sys
sys.path.append('C:/Users/gianl/Desktop/Gi/Supsi/BachelorProject/notebook/tweet_utils')
import tweets_utils

# %%
path = 'F:/COVID-19-Light/parquet/2020-08-Tweets/2020-08-2.parquet'
df = pd.read_parquet(path, engine="fastparquet")
df
# Out:
#           in_reply_to_user_id in_reply_to_screen_name  \
# 0                         NaN                    None
# 1                         NaN                    None
# 2                    807095.0                 nytimes
# 3                         NaN                    None
# 4                         NaN                    None
# ...                       ...                     ...
# 14999995                  NaN                    None
# 14999996                  NaN                    None
# 14999997                  NaN                    None
# 14999998                  NaN                    None
# 14999999                  NaN                    None
#
#                            rt_created_at  quoted_status_id  \
# 0         Wed Aug 19 22:06:29 +0000 2020               NaN
# 1         Thu Aug 20 05:40:10 +0000 2020               NaN
# 2                                   None               NaN
# 3         Mon Aug 17 18:23:37 +0000 2020               NaN
# 4         Wed Aug 19 12:18:06 +0000 2020               NaN
# ...                                  ...               ...
# 14999995  Wed Aug 26 13:00:31 +0000 2020               NaN
# 14999996  Fri Aug 07 09:54:25 +0000 2020               NaN
# 14999997                            None      1.298592e+18
# 14999998  Wed Aug 26 10:11:00 +0000 2020               NaN
# 14999999                            None               NaN
#
#                                                    hashtags  \
# 0                                                        []
# 1                                                        []
# 2                                                        []
# 3                                                        []
# 4                                                        []
# ...                                                     ...
# 14999995        [{'text': 'StayHome', 'indices': [60, 69]}]
# 14999996  [{'text': 'COVID19', 'indices': [110, 118]}, {...
# 14999997                                                 []
# 14999998                                                 []
# 14999999                                                 []
#
#                                                        urls
# 0                                                        []
# 1                                                        []
# 2                                                        []
# 3                                                        []
# 4                                                        []
# ...                                                     ...
# 14999995                                                 []
# 14999996  [{'url': 'https://t.co/aHKjDHvZoH', 'expanded_...
# 14999997  [{'url': 'https://t.co/0NcuwcsqLK', 'expanded_...
# 14999998                                                 []
# 14999999                                                 []
#
# [15000000 rows x 6 columns]
