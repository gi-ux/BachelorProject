# %%
import pandas as pd
import plotly.graph_objects as go
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import datetime
import plotly.express as px
import math
import warnings
warnings.filterwarnings('ignore')
import time
from time import perf_counter
import glob
import tweets_utils
import csv
import importlib
import seaborn as sns
path = glob.glob("C:/Users/gianl/Desktop/Gi/Supsi/BachelorProject/")
# %autosave 3600
# Out:
# Autosaving every 3600 seconds

# %% [markdown]
# ## Indice
# - [Check if the users are inside current data](#check)
# - [Collecting data and create DataFrame](#collecting_350)

# %%
# x = pd.DataFrame(x, columns=["screen_name"])
# x.to_csv("C:/Users/gianl/Desktop/Gi/Supsi/BachelorProject/csv/300_good_users.csv", 
#          line_terminator="\n", index=False, encoding="utf-8")

# %%
df = pd.read_csv(path[0] + "/csv/350_good_users.csv", low_memory=False, lineterminator="\n")

# %%
df
# Out:
#         screen_name
# 0    HelenBranswell
# 1         mlipsitch
# 2             trvrb
# 3            kakape
# 4      JeremyFarrar
# ..              ...
# 345    greg_folkers
# 346         ISARIC1
# 347        WHOGOARN
# 348      jmayer0716
# 349     robyn_s_lee
#
# [350 rows x 1 columns]

# %% [markdown]
# # Check if 350 good users are inside current data
# <a id="check"/>

# %%
files_tweets = glob.glob("F:/Supsi/COVID-19-Tweets/*/tweets.csv")
user_screen_name = []
cols_tweets = [u'user_screen_name']

# %%
result = []
importlib.reload(tweets_utils)
start_time = time.perf_counter()
j = 0
for filename in files_tweets:
    print(f"Reading file: {filename}")
    result.extend(tweets_utils.process_all_data(filename, cols_tweets, True, list(df["screen_name"])))
    lista = result[j]
    j = j + 1
    print(f"Mese numero {j}")
    for i in range(len(lista)):

        user_screen_name.extend(lista[i]["users"])
stop_time = time.perf_counter()
print("Time: ",stop_time-start_time)

# %%
lst_found = list(set(user_screen_name))
val_350 = len(df["screen_name"])
val_found = len(user_screen_name)
print(f"{round(val_found/val_350,2)}%")
print(f"presenti in {len(lst_found)}")
# Out:
# 93.66%
# presenti in 338

# %%
diff = list(set(df["screen_name"]) - set(lst_found))
diff

# %% [markdown]
# # Collecting data
# <a id="collecting_350" />

# %%
cols = [
    u'id',u'user_id',u'user_screen_name',u'urls', u'hashtags',
    u'rt_user_screen_name', u'rt_user_id', 
    u'in_reply_to_screen_name', u'in_reply_to_user_id', 'created_at', 'retweet_count']

# %%
result = []
data = pd.DataFrame()
importlib.reload(tweets_utils)
start_time = time.perf_counter()
j = 0
for filename in files_tweets:
    print(f"Reading file: {filename}")
    result.extend(tweets_utils.process_all_data(filename, cols, True, df["screen_name"]))
    lista = result[j]
    j = j + 1
    print(f"Mese numero {j}")
    for i in range(len(lista)):
        data = data.append(lista[i]["df"])
    print(len(data))
stop_time = time.perf_counter()
print("Time: ",stop_time-start_time)
# Out:
# Reading file: F:/Supsi/COVID-19-Tweets\2020-01\tweets.csv
# Processing chunk 1
# Processing chunk 2
# Processing chunk 3
# Processing chunk 4
# Processing chunk 5
# Mese numero 1
# 142701
# Reading file: F:/Supsi/COVID-19-Tweets\2020-02\tweets.csv
# Processing chunk 1
# Processing chunk 2
# Processing chunk 3
# Processing chunk 4
# Processing chunk 5
# Processing chunk 6
# Processing chunk 7
# Processing chunk 8
# Processing chunk 9
# Processing chunk 10
# Processing chunk 11
# Processing chunk 12
# Mese numero 2
# 376052
# Reading file: F:/Supsi/COVID-19-Tweets\2020-03\tweets.csv
# Processing chunk 1
# Processing chunk 2
# Processing chunk 3
# Processing chunk 4
# Processing chunk 5
# Processing chunk 6
# Processing chunk 7
# Processing chunk 8
# Processing chunk 9
# Processing chunk 10
# Processing chunk 11
# Processing chunk 12
# Processing chunk 13
# Processing chunk 14
# Processing chunk 15
# Mese numero 3
# 718469
# Reading file: F:/Supsi/COVID-19-Tweets\2020-04\tweets.csv
# Processing chunk 1
# Processing chunk 2
# Processing chunk 3
# Processing chunk 4
# Processing chunk 5
# Processing chunk 6
# Processing chunk 7
# Processing chunk 8
# Processing chunk 9
# Processing chunk 10
# Processing chunk 11
# Processing chunk 12
# Processing chunk 13
# Mese numero 4
# 907092
# Reading file: F:/Supsi/COVID-19-Tweets\2020-05\tweets.csv
# Processing chunk 1
# Processing chunk 2
# Processing chunk 3
# Processing chunk 4
# Processing chunk 5
# Processing chunk 6
# Processing chunk 7
# Processing chunk 8
# Processing chunk 9
# Processing chunk 10
# Processing chunk 11
# Processing chunk 12
# Processing chunk 13
# Processing chunk 14
# Processing chunk 15
# Processing chunk 16
# Processing chunk 17
# Processing chunk 18
# Processing chunk 19
# Processing chunk 20
# Processing chunk 21
# Processing chunk 22
# Processing chunk 23
# Processing chunk 24
# Mese numero 5
# 1270952
# Time:  1690.8349991999999

# %%
data
# Out:
#                            id                      created_at       user_id  \
# 2         1219768903116607488  Tue Jan 21 23:49:03 +0000 2020  4.260338e+08
# 4         1219755288988798981  Tue Jan 21 22:54:57 +0000 2020  7.380005e+17
# 6         1219753292571594754  Tue Jan 21 22:47:01 +0000 2020  3.383324e+07
# 20        1219770194379386881  Tue Jan 21 23:54:11 +0000 2020  7.648241e+17
# 28        1219769479938351105  Tue Jan 21 23:51:20 +0000 2020  4.421719e+08
# ...                       ...                             ...           ...
# 23415469  1257299901416910848  Mon May 04 13:23:50 +0000 2020  2.513344e+08
# 23415586  1260025927406243840  Tue May 12 01:56:05 +0000 2020  2.416479e+09
# 23415676  1262045509516173312  Sun May 17 15:41:11 +0000 2020  3.842185e+09
# 23415850  1265673260806672390  Wed May 27 15:56:35 +0000 2020  7.665992e+07
# 23415861  1266226534051975168  Fri May 29 04:35:05 +0000 2020  8.103540e+07
#
#          user_screen_name  retweet_count  in_reply_to_user_id  \
# 2              HHSRegion8         1123.0                  NaN
# 4              beerhowell         2224.0                  NaN
# 6            IAmTonyaNash           15.0                  NaN
# 20           tinitanajltt         1123.0                  NaN
# 28             IPACCanada         1123.0                  NaN
# ...                   ...            ...                  ...
# 23415469  mrbennettsclass           48.0                  NaN
# 23415586       redtaz1951        63910.0                  NaN
# 23415676        dlynnes01        18352.0                  NaN
# 23415850        pandeamit            0.0          189868631.0
# 23415861       twodogsing         2404.0                  NaN
#
#          in_reply_to_screen_name    rt_user_id rt_user_screen_name  \
# 2                            NaN  1.465700e+08              CDCgov
# 4                            NaN  8.070950e+05             nytimes
# 6                            NaN  1.465700e+08              CDCgov
# 20                           NaN  1.465700e+08              CDCgov
# 28                           NaN  1.465700e+08              CDCgov
# ...                          ...           ...                 ...
# 23415469                     NaN  2.467791e+06      washingtonpost
# 23415586                     NaN  2.488840e+08         RonaldKlain
# 23415676                     NaN  9.390910e+05            JoeBiden
# 23415850                DrTedros           NaN                 NaN
# 23415861                     NaN  1.383272e+09            ASlavitt
#
#                                                  hashtags  \
# 2          [{'text': 'coronavirus', 'indices': [47, 59]}]
# 4                                                      []
# 6         [{'text': 'publichealth', 'indices': [30, 43]}]
# 20         [{'text': 'coronavirus', 'indices': [47, 59]}]
# 28         [{'text': 'coronavirus', 'indices': [47, 59]}]
# ...                                                   ...
# 23415469                                               []
# 23415586                                               []
# 23415676                                               []
# 23415850                                               []
# 23415861                                               []
#
#                                                        urls
# 2                                                        []
# 4                                                        []
# 6         [{'url': 'https://t.co/8kzRD1IADl', 'expanded_...
# 20                                                       []
# 28                                                       []
# ...                                                     ...
# 23415469  [{'url': 'https://t.co/ceORz1ttzs', 'expanded_...
# 23415586                                                 []
# 23415676                                                 []
# 23415850                                                 []
# 23415861                                                 []
#
# [1270952 rows x 11 columns]

# %%
data = data.reset_index(drop = True)
data
# Out:
#                           id                      created_at       user_id  \
# 0        1219768903116607488  Tue Jan 21 23:49:03 +0000 2020  4.260338e+08
# 1        1219755288988798981  Tue Jan 21 22:54:57 +0000 2020  7.380005e+17
# 2        1219753292571594754  Tue Jan 21 22:47:01 +0000 2020  3.383324e+07
# 3        1219770194379386881  Tue Jan 21 23:54:11 +0000 2020  7.648241e+17
# 4        1219769479938351105  Tue Jan 21 23:51:20 +0000 2020  4.421719e+08
# ...                      ...                             ...           ...
# 1270947  1257299901416910848  Mon May 04 13:23:50 +0000 2020  2.513344e+08
# 1270948  1260025927406243840  Tue May 12 01:56:05 +0000 2020  2.416479e+09
# 1270949  1262045509516173312  Sun May 17 15:41:11 +0000 2020  3.842185e+09
# 1270950  1265673260806672390  Wed May 27 15:56:35 +0000 2020  7.665992e+07
# 1270951  1266226534051975168  Fri May 29 04:35:05 +0000 2020  8.103540e+07
#
#         user_screen_name  retweet_count  in_reply_to_user_id  \
# 0             HHSRegion8         1123.0                  NaN
# 1             beerhowell         2224.0                  NaN
# 2           IAmTonyaNash           15.0                  NaN
# 3           tinitanajltt         1123.0                  NaN
# 4             IPACCanada         1123.0                  NaN
# ...                  ...            ...                  ...
# 1270947  mrbennettsclass           48.0                  NaN
# 1270948       redtaz1951        63910.0                  NaN
# 1270949        dlynnes01        18352.0                  NaN
# 1270950        pandeamit            0.0          189868631.0
# 1270951       twodogsing         2404.0                  NaN
#
#         in_reply_to_screen_name    rt_user_id rt_user_screen_name  \
# 0                           NaN  1.465700e+08              CDCgov
# 1                           NaN  8.070950e+05             nytimes
# 2                           NaN  1.465700e+08              CDCgov
# 3                           NaN  1.465700e+08              CDCgov
# 4                           NaN  1.465700e+08              CDCgov
# ...                         ...           ...                 ...
# 1270947                     NaN  2.467791e+06      washingtonpost
# 1270948                     NaN  2.488840e+08         RonaldKlain
# 1270949                     NaN  9.390910e+05            JoeBiden
# 1270950                DrTedros           NaN                 NaN
# 1270951                     NaN  1.383272e+09            ASlavitt
#
#                                                 hashtags  \
# 0         [{'text': 'coronavirus', 'indices': [47, 59]}]
# 1                                                     []
# 2        [{'text': 'publichealth', 'indices': [30, 43]}]
# 3         [{'text': 'coronavirus', 'indices': [47, 59]}]
# 4         [{'text': 'coronavirus', 'indices': [47, 59]}]
# ...                                                  ...
# 1270947                                               []
# 1270948                                               []
# 1270949                                               []
# 1270950                                               []
# 1270951                                               []
#
#                                                       urls
# 0                                                       []
# 1                                                       []
# 2        [{'url': 'https://t.co/8kzRD1IADl', 'expanded_...
# 3                                                       []
# 4                                                       []
# ...                                                    ...
# 1270947  [{'url': 'https://t.co/ceORz1ttzs', 'expanded_...
# 1270948                                                 []
# 1270949                                                 []
# 1270950                                                 []
# 1270951                                                 []
#
# [1270952 rows x 11 columns]

# %%
# data = data.reset_index(drop = True)
path = glob.glob("C:/Users/gianl/Desktop/Gi/Supsi/BachelorProject/large_files/")
data.to_csv(path[0] + "all_good_users.csv", index = False, line_terminator = "\n", encoding = "utf-8")

# %% [markdown]
# # Activity
# <a id="activity"/>

# %%
path = glob.glob("C:/Users/gianl/Desktop/Gi/Supsi/BachelorProject/large_files/")
df = pd.read_csv(path[0] + "all_good_users.csv", low_memory=False, lineterminator = "\n")
df
# Out:
#                         id                      created_at       user_id  \
# 0      1219783336081539073  Wed Jan 22 00:46:24 +0000 2020  1.352962e+09
# 1      1219810588873961473  Wed Jan 22 02:34:42 +0000 2020  1.071979e+18
# 2      1219903528967249925  Wed Jan 22 08:44:00 +0000 2020  3.528640e+08
# 3      1219915043896119296  Wed Jan 22 09:29:46 +0000 2020  1.352962e+09
# 4      1219915530355666944  Wed Jan 22 09:31:42 +0000 2020  1.352962e+09
# ...                    ...                             ...           ...
# 32776  1260399384073732098  Wed May 13 02:40:04 +0000 2020  8.070950e+05
# 32777  1261351389818585088  Fri May 15 17:43:00 +0000 2020  2.611794e+07
# 32778  1265460966126485506  Wed May 27 01:53:00 +0000 2020  1.979288e+09
# 32779  1256818060050067460  Sun May 03 05:29:10 +0000 2020  1.245975e+09
# 32780  1257237738350403585  Mon May 04 09:16:49 +0000 2020  3.061632e+09
#
#       user_screen_name  retweet_count  in_reply_to_user_id  \
# 0             MackayIM           16.0                  NaN
# 1      KindrachukJason           20.0                  NaN
# 2             WHOGOARN          542.0                  NaN
# 3             MackayIM            0.0                  NaN
# 4             MackayIM            2.0                  NaN
# ...                ...            ...                  ...
# 32776          nytimes          191.0                  NaN
# 32777    SaskiaPopescu           37.0                  NaN
# 32778     DanLarremore            1.0                  NaN
# 32779         stgoldst            1.0                  NaN
# 32780     EvolveDotZoo           71.0                  NaN
#
#       in_reply_to_screen_name    rt_user_id rt_user_screen_name  \
# 0                         NaN           NaN                 NaN
# 1                         NaN  7.641714e+07            IDSAInfo
# 2                         NaN  1.898686e+08            DrTedros
# 3                         NaN           NaN                 NaN
# 4                         NaN           NaN                 NaN
# ...                       ...           ...                 ...
# 32776                     NaN           NaN                 NaN
# 32777                     NaN  2.880886e+09        gregkoblentz
# 32778                     NaN  3.967445e+07              neurdy
# 32779                     NaN           NaN                 NaN
# 32780                     NaN  1.159777e+18       OscarMacLean1
#
#                                                 hashtags  \
# 0      [{'text': 'Wuhan', 'indices': [87, 93]}, {'tex...
# 1      [{'text': 'Wuhan', 'indices': [64, 70]}, {'tex...
# 2         [{'text': 'coronavirus', 'indices': [83, 95]}]
# 3      [{'text': 'WuhanPneumonia', 'indices': [91, 10...
# 4                                                     []
# ...                                                  ...
# 32776                                                 []
# 32777                                                 []
# 32778  [{'text': 'COVID19colorado', 'indices': [20, 3...
# 32779                                                 []
# 32780                                                 []
#
#                                                     urls
# 0      [{'url': 'https://t.co/fbk6HGY3gb', 'expanded_...
# 1      [{'url': 'https://t.co/Cm8rjaZHpi', 'expanded_...
# 2                                                     []
# 3      [{'url': 'https://t.co/eTMXY7oH2O', 'expanded_...
# 4      [{'url': 'https://t.co/187Fuuj01y', 'expanded_...
# ...                                                  ...
# 32776  [{'url': 'https://t.co/aOB2mL20Js', 'expanded_...
# 32777  [{'url': 'https://t.co/LiE05sOjW5', 'expanded_...
# 32778                                                 []
# 32779  [{'url': 'https://t.co/25pu5b4qoy', 'expanded_...
# 32780                                                 []
#
# [32781 rows x 11 columns]
