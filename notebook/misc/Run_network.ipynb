# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
from time import strptime
import datetime
from datetime import datetime
import warnings
import time
import csv
import glob
import logging
import importlib
import json
import networkx as nx
import seaborn as sns
import re
from operator import itemgetter
import matplotlib.cm as mcm
import community
from community import community_louvain as cm
import leidenalg as la
import igraph as ig
from cdlib import algorithms

# %%
path = glob.glob("C:/Users/gianl/Desktop/Gi/Supsi/BachelorProject/network/network_5/")

# %%
path_nt = glob.glob("C:/Users/gianl/Desktop/Gi/Supsi/BachelorProject/network/names/")
df = pd.read_csv(path_nt[0] + "rt_nt_5.csv", lineterminator="\n", low_memory=False)
df
# Out:
#                  name          rt_name
# 0           CDC_Plays    KazuyaJohnson
# 1              m_nneo             ABC7
# 2           qayyumhsa           ajplus
# 3        tmcdonie2015        UberFacts
# 4        moodymariaaa             ABC7
# ...               ...              ...
# 2828132  mugshotqueen      skaijackson
# 2828133   pollykate98           Doaud_
# 2828134     saucenese         KaitSnod
# 2828135   SagiaOchoaa    LauraHopeGill
# 2828136     rtl371897  Jared_Phillips_
#
# [2828137 rows x 2 columns]

# %%
retweets_graph = nx.from_pandas_edgelist(df,'name','rt_name', create_using=nx.DiGraph())
print(nx.info(retweets_graph)) #da ritornare le info
# Out:
# DiGraph with 1687953 nodes and 2797889 edges

# %%
degree_dict = dict(retweets_graph.degree(retweets_graph.nodes()))
sorted_degree = sorted(degree_dict.items(), key=itemgetter(1), reverse=True)

# %%
with open(path[0] + "degree.json", 'w') as f:
    json.dump(sorted_degree, f)

# %%
in_degree_dict = dict(retweets_graph.in_degree(retweets_graph.nodes()))
sorted_in_degree = sorted(in_degree_dict.items(), key=itemgetter(1), reverse=True)

# %%
with open(path[0] + "in_degree.json", 'w') as f:
    json.dump(sorted_in_degree, f)

# %%
out_degree_dict = dict(retweets_graph.out_degree(retweets_graph.nodes()))
sorted_out_degree = sorted(out_degree_dict.items(), key=itemgetter(1), reverse=True)

# %%
with open(path[0] + "out_degree.json", 'w') as f:
    json.dump(sorted_out_degree, f)

# %% [markdown]
# ## Louvain

# %%
retweets_graph_und = nx.from_pandas_edgelist(df,'name','rt_name')
print(nx.info(retweets_graph_und))
# Out:
# Graph with 1687953 nodes and 2797174 edges

# %%
best_part = cm.best_partition(retweets_graph_und, random_state=42)

# %%
best_part
# Out:
# {'CDC_Plays': 0,
#  'KazuyaJohnson': 0,
#  'm_nneo': 1,
#  'ABC7': 1,
#  'qayyumhsa': 240,
#  'ajplus': 240,
#  'tmcdonie2015': 0,
#  'UberFacts': 252,
#  'moodymariaaa': 1,
#  'UrFellowConrad': 4,
#  'TheGOATBrady': 5,
#  'jayy_flow': 1,
#  'Ivan_DLS': 1,
#  'Crybaby_X13': 6,
#  'oscarecoy': 1,
#  'kicksdesire': 240,
#  'nofilterflo': 7,
#  'cdc_blues': 0,
#  'Ballislife': 0,
#  'OSCAr_1923': 8,
#  'OfficialJoelF': 8,
#  'Lyabah1': 7,
#  'ItsBittie': 249,
#  'Neurofourier': 249,
#  'Ludith_96': 10,
#  'johnkoolcat': 240,
#  'wilfrednky': 240,
#  'EdCastle_': 11,
#  'BOSSleidyx3': 8,
#  'wsvn': 8,
#  'Blasian_mama': 7,
#  'wsbtv': 7,
#  'brianparkbb': 252,
#  'Btong10': 8,
#  'mxbunay': 240,
#  'Swishap': 12,
#  'NoHair_DontCare': 7,
#  'Make_It_Soup': 13,
#  'DarrynMooreWSB': 14,
#  '8KuroHasu6': 15,
#  'AsapSCIENCE': 15,
#  'datara90': 15,
#  'milesdanderson': 7,
#  'pvtrickoneeill': 240,
#  'Ken_Bunnie': 16,
#  'DMRHerbs': 16,
#  'BmBooty': 240,
#  '_marcinkewicz': 1,
#  'ThehomieJoshy': 1,
#  'cbaackeXO': 1,
#  'datxraayy': 1,
#  'poweredbyjdilla': 252,
#  'OmarAsif14': 17,
#  'dAViEWAVES': 0,
#  'AMIinteriors': 8,
#  '_arielnicole': 8,
#  'Eliz5602': 252,
#  'NBA': 0,
#  'mthypenguins': 1,
#  'ProlificPimpin': 7,
#  'okkaydess': 7,
#  'Kodde_': 18,
#  'biankapijal': 240,
#  'lorrrrenaa': 1,
#  'tonyvalentiino': 8,
#  'Mariambbyx3': 8,
#  'acardenas1916': 1,
#  'wackydiva02': 1,
#  'InternationalKD': 7,
#  'Suzuki_Bj': 7,
#  'vllianz': 7,
#  'john_apple11': 1,
#  'A_N3wman': 245,
#  'LittleMinella': 252,
#  'AyeeMuffy': 7,
#  'reachghoshsoma': 15,
#  'Winter011077': 240,
#  'ShamsCharania': 0,
#  'wojespn': 0,
#  'kajaral': 20,
#  'txst_news': 20,
#  'txst': 20,
#  'Autumunnie': 240,
#  '_YoungFe': 8,
#  'Ray_chh': 0,
#  'HealthInHerHue': 21,
#  'kayy_______': 1,
#  'JesseKirschABC7': 1,
#  'lunaseclipses': 7,
#  'c__calil': 22,
#  'BKuks': 22,
#  'theGingerBair': 249,
#  'manuel_txstate': 20,
#  'thiskidjaycee': 23,
#  'AlthausDan': 252,
#  'Thaliadiaz__': 240,
#  '_babymommab': 1,
#  'Queenpizzino': 7,
#  'Cdc_14': 7,
#  'wizkhalifa': 135,
#  'alexiajwhite': 8,
#  'TxStateResearch': 20,
#  'ariesmoontweets': 25,
#  'algalpetes': 25,
#  'prodpoolF': 26,
#  'DontWalkRUN': 27,
#  'cmdiehl29': 28,
#  'JRothenbergTV': 28,
#  'curlygrlrealtor': 7,
#  'fuckyouimagirlx': 22,
#  'only1tommadden': 20,
#  'elevatdmiracles': 21,
#  'SyerraMyst': 7,
#  'ThatBPhaneece': 7,
#  'satin_ams': 7,
#  'mxnrisa': 7,
#  't_oski': 38,
#  'thegemini88': 38,
#  'MattyCatFrancis': 30,
#  'merrikate_': 31,
#  'zairesaunderss': 21,
#  'hatepickmes': 21,
#  'CaliTexasHeart': 1,
#  'BookOfNesha': 21,
#  'CheckYour_MATE': 7,
#  'Nacho_Pandaa': 0,
#  'studlyspud': 84,
#  'realsquidshady': 84,
#  'LoisLayne18': 21,
#  'honey_____g': 21,
#  'GeeEasy': 7,
#  'thebossdivaa': 33,
#  'Ana_Fernandez24': 33,
#  'abelamusic': 21,
#  'cynthiaadelrey': 245,
#  'juvz': 245,
#  'enby_epidemic': 18,
#  'literallysofie': 34,
#  'Erin_Sydnee': 7,
#  'THURSTY_JD': 7,
#  '__OT4__': 7,
#  'STLien23': 7,
#  'leanzbeans224': 31,
#  '__ryanace': 4,
#  'pmfphoenix': 4,
#  'boaremaaa': 34,
#  'alyzacaitlin': 34,
#  'THISisLULE': 14,
#  'karinalexia7': 1,
#  'elixirknome': 34,
#  'MisterLvG': 1,
#  'Oscarito_9': 7,
#  'CrackaKeef': 240,
#  'BathGod_': 1,
#  'Jacolaaaa': 1,
#  'paulwilliamsz': 1,
#  'missruthyy': 1,
#  'ewitslizeth': 0,
#  'javeauriel': 238,
#  'Luv2luvMimi': 252,
#  '_Lionessa_': 36,
#  'Alex_6411': 0,
#  'Lyndseyswears': 37,
#  'J4b4d': 1,
#  'freakincaro': 245,
#  '_fuckyoujuan': 1,
#  'AyeeLexus86': 7,
#  'Dopeassivann': 1,
#  'Gilbert_AyAr': 2,
#  'BarrettNotary': 1,
#  'af_patrol': 1,
#  'lilkassay': 1,
#  'bethie8884': 252,
#  'alondraayisel': 1,
#  'nah_foo': 7,
#  'Vanessayoung4': 1,
#  'itscmiggy': 1,
#  'StarPowerBased': 16,
#  'ellegee69': 1,
#  'Kaitttiee': 39,
#  'ethanrodriguez_': 1,
#  'kcaly82': 0,
#  'Danna_Meeks91': 1,
#  'panchiitobd': 1,
#  'tyty_15': 1,
#  'gabbzzo': 1,
#  'thetruthspotlv': 40,
#  'staytrueeeeee': 40,
#  'seamplee': 41,
#  'josie_bazan21': 0,
#  'KevinBe3090': 252,
#  'mhmkakes': 31,
#  'brattyshea': 4,
#  'skele_tea': 18,
#  'DragonRoseNana': 1,
#  'jorden_ward': 240,
#  'Mr_angrydad': 1,
#  'Maryssse': 1,
#  'ArianaTalisa': 1,
#  'CDC_YT': 42,
#  'FRANA_OW': 42,
#  'tricia_clemente': 43,
#  'JackBox': 0,
#  'ajMadeMeDoIt': 44,
#  'e1presidente': 1,
#  'ThirteenOhEight': 252,
#  'RalphJordan_': 0,
#  'farahdoesntcare': 252,
#  '_yc_ywabl': 36,
#  'FetuccineWeenie': 244,
#  'wstcoco': 7,
#  'ishantherapper': 252,
#  'mrsbrownesq': 1,
#  'thisgirlLC': 7,
#  '_skeeto_': 46,
#  'lindoraycharles': 47,
#  'dr3amsrip': 245,
#  '_chewswisely': 7,
#  'Casey_Parks12': 31,
#  'F_ernando02': 6,
#  'brrianamitchell': 6,
#  'Esi_says': 34,
#  'SHOW6ME0TYPE': 7,
#  'lindshelds': 34,
#  'rivermonsterr': 34,
#  'artisxiety': 252,
#  'kehleesiii': 48,
#  'drss420': 1,
#  'MySportsUpdate': 0,
#  'KevinF_1988_': 34,
#  'sammymarie': 34,
#  'HidalgoCounty': 20,
#  'hidalgohealth': 20,
#  '_DopeLolo': 7,
#  'teach2lift': 21,
#  'Chibi_Nova21': 41,
#  'CassandraGumbie': 1,
#  'lax4lif36': 13,
#  '_TheYin_': 49,
#  'KFOX14': 49,
#  'PelicansReddit': 34,
#  'DMGrubb': 0,
#  'TablesByChris': 0,
#  'laron_corey': 0,
#  'Primetime_Pod': 0,
#  'myracleveli_': 11,
#  'MSKUTSA': 11,
#  'youngknees': 7,
#  'BIGBABYSCUMBAG': 46,
#  'Belenprzz': 7,
#  'jonahsdoodles': 7,
#  'iamKboogie_': 47,
#  'SoundofdaCity': 47,
#  'TheMainLame2': 46,
#  'PHUNKYBRUSTER': 7,
#  'guilleezy': 7,
#  'rat_gobIin': 50,
#  'gyusdaengie': 50,
#  'lehrstueck': 34,
#  'izak_novak': 34,
#  'mighty_morgan': 1,
#  'Palepossum': 34,
#  'comradekelley': 34,
#  'whybasilbasil': 34,
#  'BLFRANKY': 40,
#  'BrennanLowKey': 34,
#  'Karl_Was_Right': 34,
#  'cairGLA': 21,
#  'donutssj4': 1,
#  'LimaWombat': 34,
#  'DaygoDiggs': 7,
#  '_Nitzaxoxo_': 7,
#  '_caramelfrap': 7,
#  'GamerPrincessXI': 18,
#  'HoochieeWhoo': 18,
#  'zian_lane': 4,
#  'Shred_MN': 51,
#  '6FatherAPP': 51,
#  'clmooree': 7,
#  'lvnette_': 11,
#  'Heatwavvee__': 7,
#  'TcatMPS': 7,
#  '_Isisssss': 7,
#  'BiggHomieStacks': 7,
#  'pleiadesaints': 34,
#  'Jon_Deluxe': 34,
#  'Jameson2245': 1,
#  'CliffGFuelCEO': 0,
#  'Work_Cooling': 7,
#  'The_Emy_Awards': 0,
#  'ALBOOGIE2011': 16,
#  'BlackLove3e': 7,
#  'fredeaux': 7,
#  'NoDisturbSign': 7,
#  'MrPrettyTony_': 7,
#  'TrueDreBlue': 7,
#  'YoungFelaKuti': 7,
#  'Chaparral_2K': 34,
#  'SnewHef': 7,
#  'robgottti': 7,
#  'Purnell_BFresh': 16,
#  'undocuphrenia': 23,
#  'brexamor': 7,
#  'Wesley8101': 0,
#  'thottiemay': 46,
#  'Jasminmarie_': 11,
#  'bhimbert1213': 0,
#  'GreennoseK': 18,
#  'redlianak': 18,
#  'CRYSInterlude': 52,
#  '24kdrank': 7,
#  'Febrezethathoe': 7,
#  'VCWalk17': 0,
#  'VCAthletics': 0,
#  '2abysses': 34,
#  'x_QueenNicole': 7,
#  'kilyamae': 7,
#  'lostnlongbeach': 7,
#  'kvngjers': 0,
#  'marleynotbob_': 1,
#  'SuperHoetastic': 7,
#  'Lexual__': 7,
#  'dr3drizzy_': 7,
#  'RanelGallardo': 7,
#  'GeminiKyyyy': 7,
#  'baby_knight52': 53,
#  'Aquariuslovech1': 53,
#  'msranique': 54,
#  'nomiseline': 54,
#  'ginnchilla': 55,
#  'ThatBoikriley': 7,
#  'Mani_Runs': 56,
#  'TOOC_Van': 7,
#  'ThatWeirdfolk': 30,
#  'MoneyTreeKi': 16,
#  'LeoBeletsky': 8,
#  '_gemgoddess': 7,
#  'Jajezlo_Allen': 7,
#  '_KingAries': 175,
#  'lovelyvene_': 7,
#  'Livelikefay': 7,
#  'LeRosie_Queen': 7,
#  'allienichole_': 59,
#  'toniitoniitonii': 59,
#  'Htx_Toothless': 7,
#  'ChargerSchools': 20,
#  'FULSHEAR_DECA': 20,
#  'Ojay_Did_it': 7,
#  'rreia_co': 7,
#  '_LavishLocs': 7,
#  'Tahsinn_09': 7,
#  'MFoxx712': 7,
#  'ReallyBars': 16,
#  '_Effar_': 18,
#  'asakid19': 60,
#  'jvicente_2': 1,
#  'jilliee_': 1,
#  'Emma_L23': 0,
#  'ChaseGrennon': 7,
#  'getsnapple': 245,
#  'LastKings_20': 7,
#  'RicoVTheG': 7,
#  'Taquitocosmico': 18,
#  'DomCellini_Art': 18,
#  'Piinkink': 1,
#  'VintageWave93': 7,
#  'AzStillBlazing': 7,
#  'Kelisxoxo': 7,
#  'GiRLiEGiRL524': 7,
#  'NanuKmp': 7,
#  'joshxysl': 46,
#  'Cryptoterra': 20,
#  'breebellezza': 7,
#  'DiveD33per': 6,
#  'butchspoonie': 34,
#  'BeebeNick': 7,
#  'McCallOfDuty': 7,
#  'elau2019': 34,
#  'G_Juulie': 61,
#  'Andychanhotin': 61,
#  'Azuya_0420': 62,
#  'yunmengshi': 34,
#  'donnacarmela': 7,
#  'FaundlyDreaming': 34,
#  'ArtofYorugami': 34,
#  'justin_sokalski': 7,
#  'SuchAhVixen': 7,
#  'pleasuredata': 34,
#  'SajTheSage': 7,
#  'DATBOYWAVY': 7,
#  'ShadowclawFC': 34,
#  'lilfayt': 34,
#  'anime_of_china': 34,
#  'LeBearPolarr': 34,
#  'sasuisgay': 34,
#  'TorikusoH': 34,
#  'SbabyShenjiu': 34,
#  'TRIPLER206': 7,
#  'syphonstrike': 34,
#  'wishmongers': 34,
#  'krissies_world': 40,
#  'askewkejon': 7,
#  'nbagleague': 0,
#  'Churchst_12': 34,
#  'metacarpi': 34,
#  'thvlln_': 7,
#  'NOVA_1111': 7,
#  'sweet_sugrplumm': 17,
#  'Memeulous': 18,
#  'periwiinkled': 34,
#  'bruhmomentirl': 18,
#  'jthipster': 34,
#  'NewBriantist': 34,
#  'real_jawbreaker': 34,
#  'FredKatz': 0,
#  'Three_sin_lines': 18,
#  'seethereyn': 34,
#  'WiseTakes': 16,
#  'gioniriley': 7,
#  'Tadicic': 34,
#  'fastbreakbreak': 0,
#  'eastbIoc': 34,
#  'SeniorSnailSnot': 34,
#  'AstralSanctum': 34,
#  'VivS17': 34,
#  'Miiscat23': 34,
#  'lovedemz129': 63,
#  'ChelseaHobbs': 63,
#  'KDN987': 18,
#  'OofyColorful': 18,
#  'liefsong': 18,
#  'draxx_on_da_twi': 42,
#  'Terremoti7': 42,
#  'JHASELALVENDAS': 42,
#  'Enam_Mozid': 17,
#  'willowhouseshop': 41,
#  'PutnamHealthNY': 41,
#  '_pauferrer_': 34,
#  'shylye_': 7,
#  'MichaelLew_': 20,
#  'ClutchPointsNBA': 0,
#  '100TypeGuanyin': 7,
#  'Ayomide62304707': 64,
#  'MarParNews': 64,
#  'rurounikendru': 42,
#  'meteo_italia7': 42,
#  'andrre2m': 42,
#  'fbmaarket': 42,
#  'HaleyHeng26': 34,
#  'cuchallain': 34,
#  '_shaycreates': 34,
#  'chunclit': 10,
#  'problematicjoz': 10,
#  'starcrossed_91': 63,
#  'taco_is_real': 240,
#  'JessiSummer': 54,
#  'iamangel1697': 1,
#  'Lilkilill': 240,
#  'BorgerKink': 34,
#  'iuhheru': 7,
#  'Raw_TKO': 7,
#  'ashenpeonies': 34,
#  'yungceofrmdawe1': 0,
#  'mymixtapez': 0,
#  'FriendoTamaego': 18,
#  'Ri_tan0513': 18,
#  'ChristinaCarlyn': 63,
#  'FranzLlyam': 18,
#  'gotamgotam': 34,
#  'hellosarahi97': 65,
#  'seselinchen39': 240,
#  'janah6698': 42,
#  'Zwandro': 66,
#  'anxuling': 66,
#  'watsdazanario': 7,
#  'russyuss': 7,
#  '_hellonasty': 34,
#  'Vkvt3': 7,
#  'MisfitMephit': 34,
#  'Kaylabonita': 7,
#  'hawkeyeguy85': 34,
#  'wil_va': 16,
#  'DisillusionedH': 34,
#  'KanSas89697750': 61,
#  'Nubianquueenn': 14,
#  'Lolthien': 14,
#  'soft_villanelle': 34,
#  'cressworths': 34,
#  'inejscrows_': 245,
#  'JaikooP_96': 34,
#  'hougk_': 20,
#  'FOX26Houston': 20,
#  '_Ntch1': 34,
#  'Peppered_Jack': 18,
#  'shoe0nhead': 18,
#  'ayeitsJOE_x': 7,
#  '50Shades_OfGhey': 7,
#  'Blz_Sil': 34,
#  'Jazz1401': 18,
#  'AngelMilk42': 34,
#  'highimpactsex': 34,
#  'asianboxing': 0,
#  'NeoRichar': 18,
#  'brainspaced': 34,
#  'brsshgtb': 240,
#  'THP_Tweetz': 67,
#  'Obsessed_W_News': 67,
#  'BeccaaaBooo96': 42,
#  'ashhleym_': 7,
#  'stevechenevey': 7,
#  'abbythepisces': 25,
#  'vivalaaaliyah': 1,
#  'getbentmo': 34,
#  'itsJello407': 7,
#  'Flo4Show': 7,
#  'fluffycloud420': 16,
#  'deyeskeyra': 7,
#  'TwoCopses': 34,
#  'meroniye': 25,
#  'panafricam': 34,
#  'firegrown': 34,
#  'MyshellebelleMy': 34,
#  'snowlattes': 34,
#  '4n_tei': 42,
#  'ccy84': 42,
#  'dadlook': 0,
#  'brent38139': 0,
#  '_tigerine': 34,
#  'pasta_good': 34,
#  'EMONEYHUNGRY': 68,
#  'brxtanny': 17,
#  'Am_ldn': 17,
#  'CallMeCarsonYT': 18,
#  'lakeemahmad': 7,
#  'cvlebknows': 7,
#  'miracide_': 18,
#  'AsianInvasion7': 42,
#  'lilpurppz': 42,
#  'tortellino22': 42,
#  'imasaveyou': 42,
#  'datga_': 18,
#  '_pianosvant_': 42,
#  'oisalex': 42,
#  'MrGeeDee_': 42,
#  'Miguelverduzc20': 42,
#  'Aoliceyy': 240,
#  'llessur_115': 42,
#  'LegoDarthMaul0': 42,
#  'JusticeGoodwin3': 42,
#  'Blanca_Narvaiz4': 42,
#  'melting_potting': 42,
#  'DaKontradiction': 51,
#  'MG_CFC10': 42,
#  'Fizz_789': 42,
#  '___jkae___': 42,
#  'stfutam': 64,
#  'Kirk_Jones15': 42,
#  'KorenPeltzer': 42,
#  'SugaDNA3': 42,
#  'RealCuddler': 18,
#  'LowDistortioner': 7,
#  'TylerMurphy__': 7,
#  'yoqueru': 42,
#  'Big4Spo': 7,
#  'lilteardrop92': 34,
#  'FelixRegino_': 42,
#  'rockstar501040': 51,
#  'Reda_OD': 42,
#  'moephistopheles': 42,
#  'CHINNGLAND': 18,
#  'dogelettuce': 64,
#  'cyvives': 18,
#  'Syy1987': 42,
#  'mellowmona_': 245,
#  'suckmy_dickb': 17,
#  'ypourgeioalith': 42,
#  'StewedSuperior7': 42,
#  'Echavez24': 0,
#  'Kolbjorn_Aklar': 18,
#  'Pazzalak': 42,
#  'NegativeRamos': 42,
#  'cesvrmm': 51,
#  'EmilianoM07': 42,
#  'TaishaJohnson': 42,
#  'p_aizuri': 42,
#  'Vantheman325': 42,
#  'zach10hulz': 42,
#  'BerryBeast76': 83,
#  'Noah115935': 42,
#  'SpillBloodForYo': 42,
#  'RedBullRem33': 42,
#  'FrozenFate__': 18,
#  'rambeau76': 42,
#  'Sol_Brando': 42,
#  'WBZTopkill': 42,
#  'joelmintea': 1,
#  'uhbot223': 42,
#  'iloveyoumingi': 55,
#  'ateezlight': 55,
#  'sammybrown24': 42,
#  'glizzypoop': 42,
#  '_poisonnn': 18,
#  'kktsune': 18,
#  'jesus_diamond24': 42,
#  'GordyAlba23': 42,
#  'Rachael_XOTWOD': 17,
#  'ReapyWeepie': 48,
#  'dwhite4451': 0,
#  'FAll5heWay': 18,
#  'omg_itsolaiman': 42,
#  'thiskidtrev': 10,
#  'DalenDuren': 42,
#  'alexpublicenemy': 42,
#  'Nathan22910': 5,
#  'marcos_solis_': 1,
#  'ShaneSheazy': 27,
#  'strwbrrysoy': 18,
#  '_ThomasTheTrain': 7,
#  'MorganFETV': 42,
#  'Nessamillion': 42,
#  'ioj122': 42,
#  'WastedMick': 18,
#  'aggreko07': 20,
#  'TicketRadio': 20,
#  'Manuelpaprez': 22,
#  'jayzuhime': 34,
#  'El_Bobbys': 22,
#  'thegremylyn': 70,
#  '68mathter_h': 42,
#  'Antonero20': 34,
#  'agikun': 34,
#  '_dannnnnnii': 1,
#  'PedroCa10584239': 20,
#  'abc13houston': 20,
#  'blackcoronus': 34,
#  'trewbryanne': 7,
#  'tha_magi': 7,
#  'Nonchalantnell': 7,
#  'VIJimbo': 34,
#  'irltho': 34,
#  'denverkong12': 0,
#  'ArsenioTheTruth': 7,
#  'SilverSurferJig': 7,
#  '1KingQuaz': 16,
#  'shopashanti': 17,
#  'SikhNasty': 17,
#  'BethBriaReports': 64,
#  'AyeYoo_Biggs': 7,
#  'BigChi3fDanny': 7,
#  'dLaurium': 42,
#  'BluSkunk147': 18,
#  'anjing_kampuss': 18,
#  'ALI3NSUNG': 245,
#  'WangXianMess': 34,
#  'angelrojas450': 71,
#  'walkmyhalls': 20,
#  'TexasMadeLV': 20,
#  'nick_shotgun': 18,
#  'ConfusedMoa': 18,
#  'GuyMomentsShow': 20,
#  'shortbhandsome': 72,
#  'thirteensriver': 1,
#  'narvaez_pol': 18,
#  'ShittyRainbow6': 18,
#  'cinpaorey': 7,
#  'Gonzitaa09': 18,
#  'Pafiru1': 34,
#  'harmonthefloor': 240,
#  'fazen74': 18,
#  'sadandsober': 240,
#  'm_ozy46': 240,
#  'coeur80s': 34,
#  'AyeeLaboy': 240,
#  'AmmarAfify': 240,
#  'DammSamm_5': 25,
#  'torrrrrence_': 25,
#  'elysiaestrada_': 73,
#  'boi_headphone': 18,
#  '__rabi3': 240,
#  'XiCarisa': 8,
#  '_annajacqueline': 54,
#  'OB_Dinero': 240,
#  'Frankiesdeadmgt': 46,
#  'asap_robyy': 46,
#  'CSamurai88': 16,
#  'ZaddyRadio': 16,
#  'Teccnutter': 18,
#  'TheNicOfTime_': 54,
#  'JamaicanLabrat': 54,
#  'sophiehurwitz': 245,
#  'Not_Alan': 20,
#  'totaliciouscool': 7,
#  'hwyteman': 42,
#  'TheRealHarry02': 42,
#  'AMQ_MANC': 42,
#  'Richie_DDL': 42,
#  'indicudd': 42,
#  'applepolka': 62,
#  'ZhugeEX': 18,
#  'SaksonoArio': 42,
#  'Rhiannon_Colton': 48,
#  'SooiMD': 48,
#  'KyoAura': 18,
#  'AnubisBasically': 18,
#  'SnomoSam': 48,
#  'Angel72_88': 42,
#  'Bombadillo42': 48,
#  'smokedsage': 48,
#  'xMitsvki': 48,
#  'ElSuavenero': 48,
#  'ChrispyBeanz': 1,
#  'Onyx_Moth': 18,
#  'SFangame': 18,
#  'justdrew247': 42,
#  'dogboyblake': 28,
#  'dippllebeck': 42,
#  '90sbabeyeah': 42,
#  'SilentXChild': 48,
#  'crowsfilms': 74,
#  'TFurstman': 18,
#  'Nate_Yankee': 42,
#  'PriaScott': 42,
#  'Haynesey76': 42,
#  'MultiFandomTay': 48,
#  'retro_aus': 42,
#  '_Unlucky17': 42,
#  'BrilliantVerve': 34,
#  'Nyaaaaaaaar': 34,
#  'IsmarDiaz4': 42,
#  'themujtabaazim': 48,
#  'JanicePaulette': 42,
#  'thereal_Unseen': 42,
#  'kntoukakis': 42,
#  'itouyas': 75,
#  'WhyMaige': 75,
#  'Giocap23': 42,
#  'eibocaj': 42,
#  'FoxFFXIV': 18,
#  'JohnVascons': 48,
#  'Tannjk': 48,
#  'defnotjose': 42,
#  'TylerJury2': 42,
#  'Quransaurus_rex': 54,
#  'alexeyduarte1': 42,
#  'DhayneMax': 42,
#  'actuallymel__': 48,
#  'Chinichi007': 18,
#  'artchurrroz': 52,
#  'ninja_kaba': 42,
#  'Shiori_Sora29': 42,
#  'bearyten': 42,
#  'slamhunnah': 48,
#  'pvsaliens': 42,
#  'ZedLeppelin224': 18,
#  'deathbysexy': 52,
#  'AstrosCounty': 52,
#  'tartsya': 48,
#  'TrollngProdigy': 42,
#  'YumikoChan': 48,
#  'UtdUmer': 48,
#  'EzzaWRLD': 48,
#  'DanielM40536113': 42,
#  'CoachScoop_': 7,
#  'jcantu0328': 7,
#  'miguelnieves464': 42,
#  'KingDescart': 18,
#  'MrThongss': 42,
#  'HolyWalker_': 76,
#  'Smithtainment': 42,
#  'ASpidersGrowth': 42,
#  'Lakaylab2': 48,
#  'umccg': 46,
#  'browncheez_': 240,
#  'sxulpturs': 48,
#  'MilesVLT': 42,
#  'Rhys_Hathaway': 42,
#  'v1tunb0tti': 42,
#  'emma_riley034': 48,
#  'Lisa56291576': 48,
#  'Angelaavrz': 42,
#  'Alexnder96': 77,
#  'KingofEloHell': 77,
#  'nedast31': 42,
#  'johnnyhghost': 48,
#  'AC3DX': 42,
#  'RustandiaV': 240,
#  'Daeva__': 42,
#  'SergMurrieta': 42,
#  'xXxOmexXx': 48,
#  'dorkitus': 42,
#  'bluist4429': 18,
#  'MacKonstantin': 18,
#  'gwenhyfer': 25,
#  '83_rico': 7,
#  'BriBlaze': 7,
#  'dedede1992': 48,
#  'cyber10mark': 18,
#  'ConsumeTheVoid': 198,
#  'ConnorRyan808': 18,
#  'JayFlores__': 42,
#  'LOVE_FAN_Tesla': 42,
#  'calmeiidaa': 42,
#  'hxvs01': 7,
#  'spikeh35': 48,
#  'haderfluffyhair': 10,
#  'rolenks': 42,
#  'dummycurse': 42,
#  'wendicasteel1': 1,
#  'starp0ster': 18,
#  'JoelPLayman': 42,
#  'SRDominatrix': 42,
#  'Chiles_T': 18,
#  'Polar5167': 18,
#  'malihamz': 17,
#  'yash31patel': 42,
#  'TheDallen198': 42,
#  'Octopi_3': 18,
#  'alejandra_mb25': 1,
#  'swag_avenger': 42,
#  'Switchbladedead': 42,
#  'thesaltraven': 48,
#  'BigTexJosh': 20,
#  'nickixalien': 48,
#  'ArtikusHG': 34,
#  'Supressoo': 7,
#  'mbo_ej': 7,
#  'hollywoodmac_': 7,
#  'TatyTheDon': 7,
#  '_chelseaa2': 7,
#  'YouAintABarbie': 7,
#  'Ttu__23': 7,
#  'theyscreaamkay': 79,
#  'FlowingZesi': 7,
#  'Howmuch4Tino': 7,
#  'AllMightyYo': 7,
#  'CherChezLaTurk': 7,
#  'Nadus': 7,
#  'nashaification': 245,
#  'Kno_Botty': 7,
#  'thegalaxys_edge': 34,
#  'surfbk7': 7,
#  'princesssmarle': 7,
#  'Colon_aa': 7,
#  'Shjsievezheheh': 18,
#  '11thDoctr': 18,
#  'FrogEnjoyer_': 80,
#  'coolzeldafan': 80,
#  'WelcomeToLevel7': 18,
#  'purplelioness4': 7,
#  'fox5dc': 7,
#  'euphrosines': 34,
#  'stormer3428': 18,
#  '__HYYERR': 81,
#  'Smashing_Ellie': 18,
#  'awkturtleartist': 34,
#  'the_shirinoff': 42,
#  'aye_stephh': 243,
#  'a_sanchez0128': 243,
#  'MarieAnyssam': 20,
#  'Nkariziki': 20,
#  'NikkuSenpai_': 83,
#  'Riixoooo': 18,
#  '_raayy_': 84,
#  'itsjessluvv': 240,
#  'bryanmaysguitar': 34,
#  'lqvetroye': 34,
#  'romansamores': 27,
#  'maraschinoheart': 27,
#  'JerusalemGreer': 231,
#  'jordantrumble': 231,
#  'fagg0ttron': 86,
#  'fabbgrat': 10,
#  'DiorDruw': 221,
#  'gradyaikens': 221,
#  'jonathanariasx': 7,
#  'rainmanix99': 49,
#  'ItzJMar': 49,
#  'monkeygat': 18,
#  'RedMarvellia': 34,
#  'bunbun_icecream': 34,
#  'lomajii': 18,
#  'WYETTHASSP0KEN': 7,
#  'DJBouknight': 7,
#  'SuperShonenStar': 18,
#  'rricxrdo': 18,
#  'dat_one_dude_11': 42,
#  'AdriannRG7': 23,
#  'eoudiaaaa': 42,
#  'Luminary_Star': 48,
#  'Jocey_99': 42,
#  'obeseman60': 18,
#  'YumiMain': 18,
#  'Roadside21': 18,
#  'Emilianodom1013': 48,
#  'PaoAlejandra122': 48,
#  'alex___gp': 48,
#  'Jameson42651607': 18,
#  'SVG_FREDDIE': 42,
#  'teriboomer': 42,
#  'enbyhq': 17,
#  'rogerchavezz': 7,
#  'kburbss': 42,
#  'xelatwt': 48,
#  'RoneciaLovee': 48,
#  'LizBrookes1984': 48,
#  'joweiinnuh': 42,
#  'SquiddOCheese': 18,
#  'spicytwat': 48,
#  'nosajtrawets': 48,
#  'Ali4773': 42,
#  'katelin_03': 42,
#  'SoaringBrain': 48,
#  'dhadjr': 42,
#  'havana_vagabond': 7,
#  'hubiefw': 42,
#  'apriansyahds': 42,
#  'ChromeCartel': 42,
#  'penishernandez0': 18,
#  'acjd_shmacjd': 48,
#  'itschicobean': 88,
#  'NurKaffee': 48,
#  'RXSTA7': 18,
#  'crescenthanster': 17,
#  'abowlofberry': 17,
#  'jackiee_bonay': 243,
#  'PatouisVuitton': 18,
#  'OneOmgg': 48,
#  'charmed_twice': 48,
#  'runswithmutts': 48,
#  'atamira_': 48,
#  'mucoui74': 42,
#  'LeprekhanKing': 48,
#  'heayyyyyy': 48,
#  'AzzBlazter': 42,
#  'RawrEksDee': 48,
#  'ariantooni': 240,
#  'erickkpenaloza': 42,
#  'emileague': 42,
#  'ellachikezie': 240,
#  'ursa_minority': 34,
#  'amirakardashian': 27,
#  'yoonslatte': 48,
#  'tdfreelancer': 48,
#  'whoismotte': 34,
#  'kimayeg': 48,
#  'JLps91': 48,
#  'LIAMWVI7': 18,
#  'puffpinkcheeks': 48,
#  'RigoTheGoat': 48,
#  'clown_police1': 48,
#  'JamieDynanMusic': 48,
#  'justadreamerr13': 48,
#  'Galactic_Voyage': 42,
#  'ugh_Reyna': 48,
#  'UGHBaangtan': 245,
#  'lokeyanhin': 42,
#  'm_adelief': 48,
#  'Kgahlis70657902': 48,
#  'BordelloValerio': 22,
#  'PepoWoodz': 22,
#  'yonimesfin': 48,
#  'TheRealTheftex': 42,
#  'jjbumbatash': 42,
#  'spoonyk_': 42,
#  'yun__juan': 18,
#  'BogarmWitch': 48,
#  'noturmami_x0': 42,
#  'steph_harmonn': 48,
#  'AmberMai12': 48,
#  'stevvvvvn': 42,
#  'ThatsVix': 48,
#  '_Kenjamin_': 48,
#  'cfckyle1': 42,
#  'Aesthesis00': 42,
#  'itsAutos': 42,
#  'fishertheone': 2,
#  '_LaughterIsJoy_': 7,
#  'babyWOLFHOUND': 16,
#  'melssan1': 48,
#  'Puppyidiot1': 48,
#  '_TRVP_GOD_12': 48,
#  'anank7': 42,
#  'DandlesMarbun': 42,
#  'AmandaMStar': 46,
#  'miguelaruizjr': 48,
#  'Saunsett': 42,
#  'Rajul_Allah': 42,
#  'DankPeng': 42,
#  'Haru_Svage': 42,
#  'ChrisByr_94': 48,
#  'N9Lifestyle': 7,
#  'Pekacho1': 42,
#  'grebbergoyle': 18,
#  'InterstellarSun': 48,
#  'Ticia_Ambitious': 48,
#  'dnitz50': 48,
#  'Plague_Doctor_D': 42,
#  'Leoojedapls': 42,
#  'foxymiraj': 48,
#  'shaspcr': 34,
#  ...}

# %%
with open(path + "louvain_communities.json", 'w') as f:
    json.dump(best_part, f)

# %%
path
# Out:
# 'C:/Users/gianl/Desktop/Gi/Supsi/BachelorProject/network/network_15'
